# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('loan_approval_dataset.csv')

# %%
data
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential   commercial  \
# 0         29900000          12           778       2400000     17600000
# 1         12200000           8           417       2700000      2200000
# 2         29700000          20           506       7100000      4500000
# 3         30700000           8           467      18200000      3300000
# 4         24200000          20           382      12400000      8200000
# ...            ...         ...           ...           ...          ...
# 4264       2300000          12           317       2800000       500000
# 4265      11300000          20           559       4200000      2900000
# 4266      23900000          18           457       1200000     12400000
# 4267      12800000           8           780       8200000       700000
# 4268      29700000          10           607      17800000     11800000
#
#         luxury     bankA  loan_status
# 0     22700000   8000000     Approved
# 1      8800000   3300000     Rejected
# 2     33300000  12800000     Rejected
# 3     23300000   7900000     Rejected
# 4     29400000   5000000     Rejected
# ...        ...       ...          ...
# 4264   3300000    800000     Rejected
# 4265  11000000   1900000     Approved
# 4266  18100000   7300000     Rejected
# 4267  14100000   5800000     Approved
# 4268  35700000  12000000     Approved
#
# [4269 rows x 13 columns]

# %%
data.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential    commercial        luxury  \
# count  4269.000000   4269.000000  4.269000e+03  4.269000e+03  4.269000e+03
# mean     10.900445    599.936051  7.472617e+06  4.973155e+06  1.512631e+07
# std       5.709187    172.430401  6.503637e+06  4.388966e+06  9.103754e+06
# min       2.000000    300.000000 -1.000000e+05  0.000000e+00  3.000000e+05
# 25%       6.000000    453.000000  2.200000e+06  1.300000e+06  7.500000e+06
# 50%      10.000000    600.000000  5.600000e+06  3.700000e+06  1.460000e+07
# 75%      16.000000    748.000000  1.130000e+07  7.600000e+06  2.170000e+07
# max      20.000000    900.000000  2.910000e+07  1.940000e+07  3.920000e+07
#
#               bankA
# count  4.269000e+03
# mean   4.976692e+06
# std    3.250185e+06
# min    0.000000e+00
# 25%    2.300000e+06
# 50%    4.600000e+06
# 75%    7.100000e+06
# max    1.470000e+07

# %%
data.drop(columns=['loan_id'],inplace = True)

# %%
data
# Out:
#       no_of_dependents      education self_employed  income_annum  \
# 0                    2       Graduate            No       9600000
# 1                    0   Not Graduate           Yes       4100000
# 2                    3       Graduate            No       9100000
# 3                    3       Graduate            No       8200000
# 4                    5   Not Graduate           Yes       9800000
# ...                ...            ...           ...           ...
# 4264                 5       Graduate           Yes       1000000
# 4265                 0   Not Graduate           Yes       3300000
# 4266                 2   Not Graduate            No       6500000
# 4267                 1   Not Graduate            No       4100000
# 4268                 1       Graduate            No       9200000
#
#       loan_amount  loan_term  cibil_score  residential  commercial    luxury  \
# 0        29900000         12          778      2400000    17600000  22700000
# 1        12200000          8          417      2700000     2200000   8800000
# 2        29700000         20          506      7100000     4500000  33300000
# 3        30700000          8          467     18200000     3300000  23300000
# 4        24200000         20          382     12400000     8200000  29400000
# ...           ...        ...          ...          ...         ...       ...
# 4264      2300000         12          317      2800000      500000   3300000
# 4265     11300000         20          559      4200000     2900000  11000000
# 4266     23900000         18          457      1200000    12400000  18100000
# 4267     12800000          8          780      8200000      700000  14100000
# 4268     29700000         10          607     17800000    11800000  35700000
#
#          bankA loan_status
# 0      8000000    Approved
# 1      3300000    Rejected
# 2     12800000    Rejected
# 3      7900000    Rejected
# 4      5000000    Rejected
# ...        ...         ...
# 4264    800000    Rejected
# 4265   1900000    Approved
# 4266   7300000    Rejected
# 4267   5800000    Approved
# 4268  12000000    Approved
#
# [4269 rows x 12 columns]

# %%
data.columns
# Out:
# Index([' no_of_dependents', ' education', ' self_employed', ' income_annum',
#        ' loan_amount', ' loan_term', ' cibil_score', ' residential',
#        ' commercial', ' luxury', ' bankA', ' loan_status'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip()

# %%
data.columns
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'residential', 'commercial',
#        'luxury', 'bankA', 'loan_status'],
#       dtype='object')

# %%
data['Assets']= data.residential + data.commercial + data.luxury + data.bankA

# %%
data
# Out:
#       no_of_dependents      education self_employed  income_annum  \
# 0                    2       Graduate            No       9600000
# 1                    0   Not Graduate           Yes       4100000
# 2                    3       Graduate            No       9100000
# 3                    3       Graduate            No       8200000
# 4                    5   Not Graduate           Yes       9800000
# ...                ...            ...           ...           ...
# 4264                 5       Graduate           Yes       1000000
# 4265                 0   Not Graduate           Yes       3300000
# 4266                 2   Not Graduate            No       6500000
# 4267                 1   Not Graduate            No       4100000
# 4268                 1       Graduate            No       9200000
#
#       loan_amount  loan_term  cibil_score  residential  commercial    luxury  \
# 0        29900000         12          778      2400000    17600000  22700000
# 1        12200000          8          417      2700000     2200000   8800000
# 2        29700000         20          506      7100000     4500000  33300000
# 3        30700000          8          467     18200000     3300000  23300000
# 4        24200000         20          382     12400000     8200000  29400000
# ...           ...        ...          ...          ...         ...       ...
# 4264      2300000         12          317      2800000      500000   3300000
# 4265     11300000         20          559      4200000     2900000  11000000
# 4266     23900000         18          457      1200000    12400000  18100000
# 4267     12800000          8          780      8200000      700000  14100000
# 4268     29700000         10          607     17800000    11800000  35700000
#
#          bankA loan_status    Assets
# 0      8000000    Approved  50700000
# 1      3300000    Rejected  17000000
# 2     12800000    Rejected  57700000
# 3      7900000    Rejected  52700000
# 4      5000000    Rejected  55000000
# ...        ...         ...       ...
# 4264    800000    Rejected   7400000
# 4265   1900000    Approved  20000000
# 4266   7300000    Rejected  39000000
# 4267   5800000    Approved  28800000
# 4268  12000000    Approved  77300000
#
# [4269 rows x 13 columns]

# %%
data.drop(columns=['luxury','bankA','residential','commercial'], inplace=True)

# %%
data
# Out:
#       no_of_dependents      education self_employed  income_annum  \
# 0                    2       Graduate            No       9600000
# 1                    0   Not Graduate           Yes       4100000
# 2                    3       Graduate            No       9100000
# 3                    3       Graduate            No       8200000
# 4                    5   Not Graduate           Yes       9800000
# ...                ...            ...           ...           ...
# 4264                 5       Graduate           Yes       1000000
# 4265                 0   Not Graduate           Yes       3300000
# 4266                 2   Not Graduate            No       6500000
# 4267                 1   Not Graduate            No       4100000
# 4268                 1       Graduate            No       9200000
#
#       loan_amount  loan_term  cibil_score loan_status    Assets
# 0        29900000         12          778    Approved  50700000
# 1        12200000          8          417    Rejected  17000000
# 2        29700000         20          506    Rejected  57700000
# 3        30700000          8          467    Rejected  52700000
# 4        24200000         20          382    Rejected  55000000
# ...           ...        ...          ...         ...       ...
# 4264      2300000         12          317    Rejected   7400000
# 4265     11300000         20          559    Approved  20000000
# 4266     23900000         18          457    Rejected  39000000
# 4267     12800000          8          780    Approved  28800000
# 4268     29700000         10          607    Approved  77300000
#
# [4269 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# no_of_dependents    0
# education           0
# self_employed       0
# income_annum        0
# loan_amount         0
# loan_term           0
# cibil_score         0
# loan_status         0
# Assets              0
# dtype: int64

# %%
data.education.unique()
# Out:
# array([' Graduate', ' Not Graduate'], dtype=object)

# %%
def clean_data(st):
    st = st.strip()
    return st

# %%
clean_data(' omkar')
# Out:
# 'omkar'

# %%
data.education = data.education.apply(clean_data)

# %%
data.education.unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
data['education'] = data['education'].replace(['Graduate', 'Not Graduate'],[1,0])
# Out:
# C:\Users\omkad\AppData\Local\Temp\ipykernel_15576\94172871.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['education'] = data['education'].replace(['Graduate', 'Not Graduate'],[1,0])

# %%
data
# Out:
#       no_of_dependents  education self_employed  income_annum  loan_amount  \
# 0                    2          1            No       9600000     29900000
# 1                    0          0           Yes       4100000     12200000
# 2                    3          1            No       9100000     29700000
# 3                    3          1            No       8200000     30700000
# 4                    5          0           Yes       9800000     24200000
# ...                ...        ...           ...           ...          ...
# 4264                 5          1           Yes       1000000      2300000
# 4265                 0          0           Yes       3300000     11300000
# 4266                 2          0            No       6500000     23900000
# 4267                 1          0            No       4100000     12800000
# 4268                 1          1            No       9200000     29700000
#
#       loan_term  cibil_score loan_status    Assets
# 0            12          778    Approved  50700000
# 1             8          417    Rejected  17000000
# 2            20          506    Rejected  57700000
# 3             8          467    Rejected  52700000
# 4            20          382    Rejected  55000000
# ...         ...          ...         ...       ...
# 4264         12          317    Rejected   7400000
# 4265         20          559    Approved  20000000
# 4266         18          457    Rejected  39000000
# 4267          8          780    Approved  28800000
# 4268         10          607    Approved  77300000
#
# [4269 rows x 9 columns]

# %%
data.self_employed.unique()
# Out:
# array([' No', ' Yes'], dtype=object)

# %%
data.self_employed = data.self_employed.apply(clean_data)

# %%
data.self_employed.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data.self_employed= data.self_employed.replace(['No', 'Yes'], [0,1])
# Out:
# C:\Users\omkad\AppData\Local\Temp\ipykernel_15576\1182536356.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.self_employed= data.self_employed.replace(['No', 'Yes'], [0,1])

# %%
data
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2          1              0       9600000     29900000
# 1                    0          0              1       4100000     12200000
# 2                    3          1              0       9100000     29700000
# 3                    3          1              0       8200000     30700000
# 4                    5          0              1       9800000     24200000
# ...                ...        ...            ...           ...          ...
# 4264                 5          1              1       1000000      2300000
# 4265                 0          0              1       3300000     11300000
# 4266                 2          0              0       6500000     23900000
# 4267                 1          0              0       4100000     12800000
# 4268                 1          1              0       9200000     29700000
#
#       loan_term  cibil_score loan_status    Assets
# 0            12          778    Approved  50700000
# 1             8          417    Rejected  17000000
# 2            20          506    Rejected  57700000
# 3             8          467    Rejected  52700000
# 4            20          382    Rejected  55000000
# ...         ...          ...         ...       ...
# 4264         12          317    Rejected   7400000
# 4265         20          559    Approved  20000000
# 4266         18          457    Rejected  39000000
# 4267          8          780    Approved  28800000
# 4268         10          607    Approved  77300000
#
# [4269 rows x 9 columns]

# %%
data.loan_status.unique()
# Out:
# array([' Approved', ' Rejected'], dtype=object)

# %%
data.loan_status = data.loan_status.apply(clean_data)

# %%
data.loan_status.unique()
# Out:
# array(['Approved', 'Rejected'], dtype=object)

# %%
data.loan_status = data.loan_status.replace(['Approved', 'Rejected'], [1,0])
# Out:
# C:\Users\omkad\AppData\Local\Temp\ipykernel_15576\3887409188.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.loan_status = data.loan_status.replace(['Approved', 'Rejected'], [1,0])

# %%
data
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2          1              0       9600000     29900000
# 1                    0          0              1       4100000     12200000
# 2                    3          1              0       9100000     29700000
# 3                    3          1              0       8200000     30700000
# 4                    5          0              1       9800000     24200000
# ...                ...        ...            ...           ...          ...
# 4264                 5          1              1       1000000      2300000
# 4265                 0          0              1       3300000     11300000
# 4266                 2          0              0       6500000     23900000
# 4267                 1          0              0       4100000     12800000
# 4268                 1          1              0       9200000     29700000
#
#       loan_term  cibil_score  loan_status    Assets
# 0            12          778            1  50700000
# 1             8          417            0  17000000
# 2            20          506            0  57700000
# 3             8          467            0  52700000
# 4            20          382            0  55000000
# ...         ...          ...          ...       ...
# 4264         12          317            0   7400000
# 4265         20          559            1  20000000
# 4266         18          457            0  39000000
# 4267          8          780            1  28800000
# 4268         10          607            1  77300000
#
# [4269 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
input_data =data.drop(columns=['loan_status'])
output_data = data['loan_status']

# %%
input_data
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2          1              0       9600000     29900000
# 1                    0          0              1       4100000     12200000
# 2                    3          1              0       9100000     29700000
# 3                    3          1              0       8200000     30700000
# 4                    5          0              1       9800000     24200000
# ...                ...        ...            ...           ...          ...
# 4264                 5          1              1       1000000      2300000
# 4265                 0          0              1       3300000     11300000
# 4266                 2          0              0       6500000     23900000
# 4267                 1          0              0       4100000     12800000
# 4268                 1          1              0       9200000     29700000
#
#       loan_term  cibil_score    Assets
# 0            12          778  50700000
# 1             8          417  17000000
# 2            20          506  57700000
# 3             8          467  52700000
# 4            20          382  55000000
# ...         ...          ...       ...
# 4264         12          317   7400000
# 4265         20          559  20000000
# 4266         18          457  39000000
# 4267          8          780  28800000
# 4268         10          607  77300000
#
# [4269 rows x 8 columns]

# %%
output_data
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4264    0
# 4265    1
# 4266    0
# 4267    1
# 4268    1
# Name: loan_status, Length: 4269, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(input_data,output_data,test_size=0.2)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((3415, 8), (854, 8), (3415,), (854,))
